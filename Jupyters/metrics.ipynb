# %% [markdown]
# # Metrics
#
# ## cyclomatic - cyclomaticDensity - maintainability - halstead

# %%
# import the pandas data analysis library and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

n_sketches_created = 14542
n_sketches_hearted = 14196
n_sketches_total = n_sketches_created + n_sketches_hearted

# %%
def scatter_plot(df, var_name, title):
    data = df[var_name]
    mean = df[var_name].mean()
    std = df[var_name].std()
    min_value = min(data)
    max_value = max(data)
    
    plt.title(title)
    plt.scatter(x=df.index, y=df[var_name], s=0.5)
    plt.hlines(y=mean, xmin=0, xmax=len(data),  colors='y')
    
    if std > 0:
        if (mean - std) > min_value:
            plt.hlines(y=mean - std, xmin=0, xmax=len(data), colors='r')

        if (mean + std) < max_value:
            plt.hlines(y=mean + std, xmin=0, xmax=len(data), colors='r')

        if (mean - 2*std) > min_value:
            plt.hlines(y=mean - 2*std, xmin=0, xmax=len(data), colors='g')

        if (mean + 2*std) < max_value:
            plt.hlines(y=mean + 2*std, xmin=0, xmax=len(data), colors='g')
            
    #hide x-axis
    ax = plt.gca()
    ax.get_xaxis().set_visible(False)

    plt.show()

# %%
# read the csv file
# df_demo_module = pd.read_csv("../demo_metrics_module.csv", index_col=0)
# df_demo_module

# %%
# df_demo_module.describe()

# %%
# scatter_plot(df_demo_module, 'cyclomatic_mod_list', "cyclomatic test func")

# %% [markdown]
# ## Modules

# %% [markdown]
# ### Created

# %%
# read the csv file
df_created_module = pd.read_csv("../analysis/cr/csvs/created_metrics_module.csv", index_col=0)
df_created_module
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# 0                    126.730056                    2
# 1                    138.391681                   12
# 2                    106.441758                   10
# 3                    171.000000                    1
# 4                    102.867311                    4
# ...                         ...                  ...
# 12115                 89.450051                    9
# 12116                120.079489                    1
# 12117                 85.217515                    1
# 12118                130.075571                    1
# 12119                157.327638                    1
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# 0                       20.000000               1078.169072
# 1                       22.641509                981.239842
# 2                       14.925373               6449.148544
# 3                             NaN                  0.000000
# ...

# %%
df_created_module.describe()
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# count              12120.000000         12120.000000
# mean                 115.452631            41.230693
# std                   27.516953           421.128282
# min                  -30.081778             1.000000
# 25%                   99.104041             1.000000
# 50%                  113.823377             2.000000
# 75%                  130.468031             5.000000
# max                  171.000000          5447.000000
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# count                11417.000000              1.212000e+04
# mean                    15.601248              5.009117e+04
# std                     16.259166              1.940210e+06
# min                      0.023452              0.000000e+00
# 25%                      7.142857              1.944070e+02
# 50%                     12.500000              1.273028e+03
# 75%                     19.047619              5.687491e+03
# ...

# %%
scatter_plot(df_created_module, 'maintainability_mod_list', "Maintainability for modules - created")
scatter_plot(df_created_module, 'cyclomatic_mod_list', "Cyclomatic complexity for modules - created")
scatter_plot(df_created_module, 'cyclomaticDensity_mod_list', "Cyclomatic Density for modules - created")

scatter_plot(df_created_module, 'effort_mod_func_avg_list', "Effort avg of funcs per module - created")
scatter_plot(df_created_module, 'cyclomatic_mod_func_avg_list', "Cyclomatic complexity avg of funcs perr modules - created")

scatter_plot(df_created_module, 'vocabulary_mod_list', "Vocabulary - Halstead Complexity for modules - created")
scatter_plot(df_created_module, 'difficulty_mod_list', "Difficulty - Halstead Complexity for modules - created")
scatter_plot(df_created_module, 'volume_mod_list', "Volume - Halstead Complexity for modules - created")
scatter_plot(df_created_module, 'effort_mod_list', "Effort - Halstead Complexity for modules - created")
scatter_plot(df_created_module, 'bugs_mod_list', "Bugs - Halstead Complexity for modules - created")
scatter_plot(df_created_module, 'time_mod_list', "Time - Halstead Complexity for modules - created")

# %% [markdown]
# ### Hearted

# %%
# read the csv file
df_hearted_module = pd.read_csv("../analysis/cr/csvs/hearted_metrics_module.csv", index_col=0)
df_hearted_module
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# 0                    110.102484                   16
# 1                    103.307887                    4
# 2                     86.820926                   33
# 3                    118.859939                   14
# 4                    102.390202                    7
# ...                         ...                  ...
# 11644                 89.450051                    9
# 11645                171.000000                    1
# 11646                 89.450051                    9
# 11647                131.286061                    3
# 11648                 50.969230                   76
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# 0                       18.390805               3642.377278
# 1                       10.810811              11367.281377
# 2                       15.942029              19220.780571
# 3                        7.407407               1378.869610
# ...

# %%
df_hearted_module.describe()
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# count              11649.000000         11649.000000
# mean                 112.201615            17.944030
# std                   25.535596           172.411143
# min                  -31.265510             1.000000
# 25%                   96.739380             2.000000
# 50%                  107.673163             5.000000
# 75%                  121.022586            10.000000
# max                  171.000000          5447.000000
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# count                10988.000000              1.164900e+04
# mean                    18.321155              3.194961e+04
# std                     18.681881              5.949078e+05
# min                      0.011028              0.000000e+00
# 25%                      9.090909              8.586346e+02
# 50%                     13.333333              3.341482e+03
# 75%                     19.673453              9.280827e+03
# ...

# %%
scatter_plot(df_hearted_module, 'maintainability_mod_list', "Maintainability for modules - hearted")
scatter_plot(df_hearted_module, 'cyclomatic_mod_list', "Cyclomatic complexity for modules - hearted")
scatter_plot(df_hearted_module, 'cyclomaticDensity_mod_list', "Cyclomatic Density for modules - hearted")

scatter_plot(df_hearted_module, 'effort_mod_func_avg_list', "Effort avg of funcs per module - hearted")
scatter_plot(df_hearted_module, 'cyclomatic_mod_func_avg_list', "Cyclomatic complexity avg of funcs perr modules - hearted")

scatter_plot(df_hearted_module, 'vocabulary_mod_list', "Vocabulary - Halstead Complexity for modules - hearted")
scatter_plot(df_hearted_module, 'difficulty_mod_list', "Difficulty - Halstead Complexity for modules - hearted")
scatter_plot(df_hearted_module, 'volume_mod_list', "Volume - Halstead Complexity for modules - hearted")
scatter_plot(df_hearted_module, 'effort_mod_list', "Effort - Halstead Complexity for modules - hearted")
scatter_plot(df_hearted_module, 'bugs_mod_list', "Bugs - Halstead Complexity for modules - hearted")
scatter_plot(df_hearted_module, 'time_mod_list', "Time - Halstead Complexity for modules - hearted")

# %% [markdown]
# ### Total

# %%
# read the csv file
df_total_module = pd.read_csv("../analysis/cr/csvs/total_metrics_module.csv", index_col=0)
df_total_module
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# 0                    126.730056                    2
# 1                    138.391681                   12
# 2                    106.441758                   10
# 3                    171.000000                    1
# 4                    102.867311                    4
# ...                         ...                  ...
# 23764                 89.450051                    9
# 23765                171.000000                    1
# 23766                 89.450051                    9
# 23767                131.286061                    3
# 23768                 50.969230                   76
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# 0                       20.000000               1078.169072
# 1                       22.641509                981.239842
# 2                       14.925373               6449.148544
# 3                             NaN                  0.000000
# ...

# %%
df_total_module.describe()
# Out:
#        maintainability_mod_list  cyclomatic_mod_list  \
# count              23769.000000         23769.000000
# mean                 113.859333            29.818082
# std                   26.613491           324.239377
# min                  -31.265510             1.000000
# 25%                   97.683588             1.000000
# 50%                  110.353993             3.000000
# 75%                  126.498345             7.000000
# max                  171.000000          5447.000000
#
#        cyclomaticDensity_mod_list  effort_mod_func_avg_list  \
# count                22405.000000              2.376900e+04
# mean                    16.935162              4.120013e+04
# std                     17.541702              1.446704e+06
# min                      0.011028              0.000000e+00
# 25%                      8.333333              3.437907e+02
# 50%                     12.903226              2.216404e+03
# 75%                     19.277108              7.710428e+03
# ...

# %%
scatter_plot(df_total_module, 'maintainability_mod_list', "Maintainability for modules - total")
scatter_plot(df_total_module, 'cyclomatic_mod_list', "Cyclomatic complexity for modules - total")
scatter_plot(df_total_module, 'cyclomaticDensity_mod_list', "Cyclomatic Density for modules - total")

scatter_plot(df_total_module, 'effort_mod_func_avg_list', "Effort avg of funcs per module - total")
scatter_plot(df_total_module, 'cyclomatic_mod_func_avg_list', "Cyclomatic complexity avg of funcs perr modules - total")

scatter_plot(df_total_module, 'vocabulary_mod_list', "Vocabulary - Halstead Complexity for modules - total")
scatter_plot(df_total_module, 'difficulty_mod_list', "Difficulty - Halstead Complexity for modules - total")
scatter_plot(df_total_module, 'volume_mod_list', "Volume - Halstead Complexity for modules - total")
scatter_plot(df_total_module, 'effort_mod_list', "Effort - Halstead Complexity for modules - total")
scatter_plot(df_total_module, 'bugs_mod_list', "Bugs - Halstead Complexity for modules - total")
scatter_plot(df_total_module, 'time_mod_list', "Time - Halstead Complexity for modules - total")

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Created

# %%
# read the csv file
df_created_func = pd.read_csv("../analysis/cr/csvs/created_metrics_func.csv", index_col=0)
df_created_func
# Out:
#         cyclomatic_func_list  cyclomaticDensity_func_list  \
# 0                          2                    33.333333
# 1                          1                   100.000000
# 2                          1                   100.000000
# 3                          1                   100.000000
# 4                          1                   100.000000
# ...                      ...                          ...
# 279999                     1                     1.818182
# 280000                     1                    20.000000
# 280001                     1                    33.333333
# 280002                     1                    50.000000
# 280003                     1                   100.000000
#
#         vocabulary_func_list  difficulty_func_list  volume_func_list  \
# 0                         31              8.525000        252.664012
# 1                          3              0.500000          4.754888
# ...

# %%
df_created_func.describe() ### skips the NaNs
# Out:
#        cyclomatic_func_list  cyclomaticDensity_func_list  \
# count         280004.000000                277445.000000
# mean               2.740957                    81.704987
# std                4.863832                    83.046378
# min                1.000000                     0.029707
# 25%                1.000000                    33.333333
# 50%                2.000000                    61.538462
# 75%                3.000000                   100.000000
# max              234.000000                  1300.000000
#
#        vocabulary_func_list  difficulty_func_list  volume_func_list  \
# count         280004.000000         280004.000000      2.800040e+05
# mean              23.433133              9.051445      4.344174e+02
# std              101.337357             12.834335      4.248888e+03
# min                0.000000              0.000000      0.000000e+00
# 25%                9.000000              2.216074      4.318507e+01
# ...

# %%
scatter_plot(df_created_func, 'cyclomatic_func_list', "Cyclomatic complexity for funcs - created")
scatter_plot(df_created_func, 'cyclomaticDensity_func_list', "Cyclomatic Density for funcs - created")

scatter_plot(df_created_func, 'vocabulary_func_list', "Vocabulary - Halstead Complexity for funcs - created")
scatter_plot(df_created_func, 'difficulty_func_list', "Difficulty - Halstead Complexity for funcs - created")
scatter_plot(df_created_func, 'volume_func_list', "Volume - Halstead Complexity for funcs - created")
scatter_plot(df_created_func, 'effort_func_list', "Effort - Halstead Complexity for funcs - created")
scatter_plot(df_created_func, 'bugs_func_list', "Bugs - Halstead Complexity for funcs - created")
scatter_plot(df_created_func, 'time_func_list', "Time - Halstead Complexity for funcs - created")

# %% [markdown]
# ### Hearted

# %%
# read the csv file
df_hearted_func = pd.read_csv("../analysis/cr/csvs/hearted_metrics_func.csv", index_col=0)
df_hearted_func
# Out:
#         cyclomatic_func_list  cyclomaticDensity_func_list  \
# 0                          3                    60.000000
# 1                          1                    25.000000
# 2                          1                    33.333333
# 3                          4                    22.222222
# 4                          2                    40.000000
# ...                      ...                          ...
# 110988                     1                    16.666667
# 110989                     3                    60.000000
# 110990                     1                   100.000000
# 110991                     4                    44.444444
# 110992                    73                    32.017544
#
#         vocabulary_func_list  difficulty_func_list  volume_func_list  \
# 0                         21              4.200000        153.731110
# 1                         12              1.000000         53.774438
# ...

# %%
df_hearted_func.describe()
# Out:
#        cyclomatic_func_list  cyclomaticDensity_func_list  \
# count         110993.000000                109743.000000
# mean               2.776689                    62.708014
# std                5.728863                    64.247447
# min                1.000000                     0.003594
# 25%                1.000000                    23.809524
# 50%                2.000000                    44.444444
# 75%                3.000000                   100.000000
# max              954.000000                  1300.000000
#
#        vocabulary_func_list  difficulty_func_list  volume_func_list  \
# count         110993.000000         110993.000000      1.109930e+05
# mean              26.328606              9.623690      5.568882e+02
# std              297.340749             14.756813      1.254814e+04
# min                0.000000              0.000000      0.000000e+00
# 25%                9.000000              2.250000      4.437895e+01
# ...

# %%
scatter_plot(df_hearted_func, 'cyclomatic_func_list', "Cyclomatic complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'cyclomaticDensity_func_list', "Cyclomatic Density for funcs - hearted")

scatter_plot(df_hearted_func, 'vocabulary_func_list', "Vocabulary - Halstead Complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'difficulty_func_list', "Difficulty - Halstead Complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'volume_func_list', "Volume - Halstead Complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'effort_func_list', "Effort - Halstead Complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'bugs_func_list', "Bugs - Halstead Complexity for funcs - hearted")
scatter_plot(df_hearted_func, 'time_func_list', "Time - Halstead Complexity for funcs - hearted")

# %% [markdown]
# ### Total

# %%
# read the csv file
df_total_func = pd.read_csv("../analysis/cr/csvs/total_metrics_func.csv", index_col=0)
df_total_func
# Out:
#         cyclomatic_func_list  cyclomaticDensity_func_list  \
# 0                          2                    33.333333
# 1                          1                   100.000000
# 2                          1                   100.000000
# 3                          1                   100.000000
# 4                          1                   100.000000
# ...                      ...                          ...
# 390992                     1                    16.666667
# 390993                     3                    60.000000
# 390994                     1                   100.000000
# 390995                     4                    44.444444
# 390996                    73                    32.017544
#
#         vocabulary_func_list  difficulty_func_list  volume_func_list  \
# 0                         31              8.525000        252.664012
# 1                          3              0.500000          4.754888
# ...

# %%
df_total_func.describe()
# Out:
#        cyclomatic_func_list  cyclomaticDensity_func_list  \
# count         390997.000000                387188.000000
# mean               2.751100                    76.320562
# std                5.124272                    78.645785
# min                1.000000                     0.003594
# 25%                1.000000                    28.571429
# 50%                2.000000                    50.000000
# 75%                3.000000                   100.000000
# max              954.000000                  1300.000000
#
#        vocabulary_func_list  difficulty_func_list  volume_func_list  \
# count         390997.000000         390997.000000      3.909970e+05
# mean              24.255076              9.213889      4.691834e+02
# std              180.147647             13.410582      7.591330e+03
# min                0.000000              0.000000      0.000000e+00
# 25%                9.000000              2.250000      4.318507e+01
# ...

# %%
scatter_plot(df_total_func, 'cyclomatic_func_list', "Cyclomatic complexity for funcs - total")
scatter_plot(df_total_func, 'cyclomaticDensity_func_list', "Cyclomatic Density for funcs - total")

scatter_plot(df_total_func, 'vocabulary_func_list', "Vocabulary - Halstead Complexity for funcs - total")
scatter_plot(df_total_func, 'difficulty_func_list', "Difficulty - Halstead Complexity for funcs - total")
scatter_plot(df_total_func, 'volume_func_list', "Volume - Halstead Complexity for funcs - total")
scatter_plot(df_total_func, 'effort_func_list', "Effort - Halstead Complexity for funcs - total")
scatter_plot(df_total_func, 'bugs_func_list', "Bugs - Halstead Complexity for funcs - total")
scatter_plot(df_total_func, 'time_func_list', "Time - Halstead Complexity for funcs - total")
